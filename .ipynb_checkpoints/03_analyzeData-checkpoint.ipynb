# %% [markdown]
# # Asking questions, Analyzing data and Reflection #

# %% [markdown]
# ## Import các thư viện cần thiết và load dữ liệu vào pandas dataframe ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Current stable release for CPU and GPU (tensorflow version >=2.00)
# !pip install --upgrade pip
# !pip install tensorflow
# install hugging face sentiment analysis pretrained model
# !pip install -q transformers
from transformers import pipeline
# Out:
# Requirement already satisfied: pip in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (23.3.2)
# Requirement already satisfied: tensorflow in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (2.15.0.post1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (1.24.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.25.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# 2023-12-26 18:52:42.975245: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-26 18:52:42.975363: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-26 18:52:42.976330: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-26 18:52:42.982792: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-26 18:52:43.860858: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load dữ liệu vào pandas dataframe
data = pd.read_csv('Data/FPL_tweets.csv', delimiter=',')
data.sample(5)
# Out:
#                   ID                  Timestamp             User  \
# 48179   7.713000e+17  2016-09-01 10:52:13+00:00   Valentine_MGMT
# 77387   1.160920e+18  2019-08-12 14:11:55+00:00    Khaleedfarouk
# 93713   1.441020e+18  2021-09-23 13:01:05+00:00  SportNe29208748
# 111446  1.635790e+18  2023-03-15 00:06:28+00:00   OriginallyDave
# 21936   5.386950e+17  2014-11-29 14:06:29+00:00   BabajideFadoju
#
#                                                      Text  \
# 48179   Join English Premier League 2016/17 - my Fanta...
# 77387   If you have problem with ur premier fantasy le...
# 93713   Premier League fantasy football tips: Ronaldo,...
# 111446  @BigManBakar @OfficialFPL There is little poin...
# 21936   Oh shit!\nSold Welbeck to buy Giroud\nFelt he'...
#
#                                         Hashtag  Retweets  Likes  Replies  \
# 48179                                       NaN         0      0        0
# 77387                                       NaN         0      1        0
# 93713   ['sport', 'news', 'soccer', 'football']         0      0        0
# 111446                                      NaN         0      8        0
# 21936                         ['WBAARS', 'ARS']         0      0        0
#
#                                                    Source  \
# 48179   <a href="http://twitter.com" rel="nofollow">Tw...
# 77387   <a href="http://twitter.com/download/iphone" r...
# 93713   <a href="https://buffer.com" rel="nofollow">Bu...
# 111446  <a href="http://twitter.com/download/android" ...
# 21936   <a href="http://twitter.com" rel="nofollow">Tw...
#
#                            Location  Verified_Account  Followers  Following
# 48179   Africa/Europe/America/Asia              False       4670       2599
# 77387                       Nigeria             False        759        779
# 93713                           NaN             False        191        101
# 111446                          NaN             False        411        265
# 21936                         Grace             False      22415       2254

# %% [markdown]
# **Ý nghĩa của mỗi cột**
#
# | Tên cột  | Ý nghĩa  |
# |---|---|
# | ID  | Mã định danh độc nhất cho mỗi tweet  |
# | Timestamp  | Ngày giờ tweet được đăng tải  |
# | User  | Tên tài khoản đăng tải tweet  |
# | Text  | Nội dung của tweet  |
# | Hashtag  | Hashtag của tweet (nếu có)  |
# | Retweets  | Số lần tweet được retweet  |
# | Likes  | Lượt like của tweet |
# | Replies  | Lượt phản hồi của tweet  |
# | Source  | Nguồn hoặc thiết bị đăng tải tweet  |
# | Location  | Địa điểm được đề cập ở hồ sơ của tài khoản đăng tải tweet (nếu có)  |
# | Verified_Account  | Trạng thái xác minh của tài khoản (TRUE hoặc FALSE)   |
# | Followers  | Số lượng tài khoản theo dõi của tài khoản đăng tải tweet  |
# | Following  | Số lượng tài khoản mà tài khoản đăng tải tweet theo dõi |
#
# *Thông tin của dữ liệu (likes, replies....) được ghi nhận tại thời điểm thu thập dữ liệu và có thể thay đổi ở thời điểm hiện tại.*

# %% [markdown]
# ## I - Đặt câu hỏi có ý nghĩa ##

# %% [markdown]
# ### 1. Các tài khoản đã xác minh thường sử dụng nguồn nào để đăng tweet? ###

# %% [markdown]
# - **Mục đích**: Khám phá các ứng dụng hoặc thiết bị mà các tài khoản đã xác minh thường sử dụng để đăng tweet về FPL.
# - **Phân tích**:
#     + Đầu tiên, tìm những tài khoản nào nào có ``Verified_Account`` là ``True`` (những tài khoản đã được xác minh).
#     + Đếm số lượng tài khoản đã xác minh đó dựa vào ``Source``. Các nguồn thường được các tài khoản đã xác minh cũng chính là top 3 số lượng tài khoản đã xác minh dựa vào ``Source`` cao nhất.

# %% [markdown]
# ### 2. Vào năm 2023, khung giờ đăng các tweets của top 10 người có số lượng followers nhiều nhất thường phổ biến nhất vào lúc nào?  ###

# %% [markdown]
# - **Mục đích**: Xác định thời gian (khung giờ) phổ biến nhất mà các tài khoản có nhiều người theo dõi thường đăng tweet về FPL.
# - **Phân tích**:
#     + Tìm những tweets được đăng vào năm 2023
#     + Tìm những tài khoản có top 10 số lượng followers nhiều nhất
#     + Phân tích số lượng followers cũa mỗi tweet dựa vào khung giờ và chọn ra số lượng lớn nhất.

# %% [markdown]
# ### 3. Các user nào không được xác minh mà sở hữu  top 10 tweets có lượng tương tác nhiều nhất? ###

# %% [markdown]
# - **Mục đích**: Xác định liệu rằng các tài khoản không được xác minh viết tweet có nhiều lượng tương tác nhất thì nội dung có chính xác hay không. Từ đó có thể phân tích xu hướng cộng đồng của mọi người hướng đến những tài khoản không xác minh này.
# - **Phân tích**:
#     + Lọc những tài khoản ``Verified_Account`` là ``True`` (những tài khoản đã được xác minh).
#     + Đếm số lượng tương tác (Tổng của ``Likes``, ``Replies``, ``Retweets``)
#     + Chọn top những tài khoản có lượng tương tác ở tweet lớn nhất (1 tài khoản có thể có nhiều tweet).

# %% [markdown]
# ### 4. Qua từng năm, những hashtag nào được tương tác nhiều nhất của các tài khoản được xác minh?  ###

# %% [markdown]
# - **Mục đích**: Giúp ta hiểu rõ về chiến lược truyền thông, nắm bắt xu hướng cộng đồng, tối ưu hóa nội dung, hơn thế nữa có thể dự đoán xu hướng tương lai.
# - **Phân tích**:
#     + Tách những ``Hashtag`` gộp (1 ``Hashtag`` là ['ITsupport', 'Tech'] sẽ thành 2 ``Hashtag`` ['ITsupport'],[ 'Tech'])
#     + Lọc những tài khoản ``Verified_Account`` là ``True`` (những tài khoản đã được xác minh).
#     + Đếm số lượng tương tác (``Likes``, ``Replies``, ``Retweets``)
#     + Chọn top 3 ``Hashtag`` có lượng tương tác lớn nhất mỗi năm

# %% [markdown]
# ### 5. Thái độ hưởng ứng của cộng đồng đối với các sự kiện (hashtag)

# %% [markdown]
# * **Nội dung**: khảo sát thái độ (tích cực, tiêu cực) của cộng đồng đối với các sự kiện phổ biến đã được tổ chức cho tựa game FPL.
# * **Mục đích**: dựa vào kết quả khảo sát, nhà phát hành có thể tiếp tục phát triển những sự kiện tích cực (mang lại giá trị cao) và hạn chế các sự kiện tiêu cực (các sự kiện nổi lên vì tai tiếng).
# * **Phân tích**:
#     * Tạo một dataframe với các cột `['hashtag_name', 'count', 'positive_text', 'negative_text']` với: `hashtag_name`: tên của hashtag và độc nhất cho mỗi sự kiện; `count`: số lần hashtag xuất hiện trong tất cả tweet, giúp xác định độ phổ biến của hashtag; `positive_text` và `negative_text` lần lượt là số lượng bình luận tích cực và tiêu cực của cộng đồng đối với hashtag.
#     * Quy trình thực hiện: bước 1 - tìm và đếm số lần xuất hiện của các hashtag. Bước 2 - tìm và phân loại (sentiment analysis) nội dung của các tweet có hashtag tương ứng.
#     * Vẽ biểu đồ cột đôi trực quan cho kết quả đạt được.

# %% [markdown]
# ## II - Tiền xử lý dữ liệu ##

# %% [markdown]
# *Lấy lại code tiền xử lý từ file 02_exploringData.ipynb*

# %% [markdown]
# **Tiền xử lý - chuyển kiểu dữ liệu của các cột dữ liệu**

# %%
# Cột ID
data['ID'] = data['ID'].astype(str)

# Cột timestamp
data['Timestamp'] = pd.to_datetime(data['Timestamp'], utc=True)

# Cột hashtag
def hashtag_pre(s):
    '''
    Tiền xử lý dữ liệu ở cột Hashtag (dữ liệu ở biến s):
    1. Loại bỏ các ký tự []''
    2. Chuyển các phần tử được phân cách bởi dấu phẩy vào list.

    Ví dụ thực thi:
    >>> test = hashtag_pre("['FPL', 'FPLCommunity']")
    >>> test, type(test), len(test)
    (['FPL', ' FPLCommunity'], list, 2)
    
    '''
    if type(s) != float:
        # Chuyển kiểu dữ liệu sang string
        result = str(s)
        
        # Loại bỏ ký tự
        chars = "[]'' "
        for char in chars:
            result = result.replace(char, '')

        # Chuyển các ký tự thành chữ thường
        result = result.lower()
        
        # Lưu trữ kết quả vào list
        result = list(result.split(','))
        
        return result
    else:
        return s

data['Hashtag'] = data['Hashtag'].apply(hashtag_pre)

# %% [markdown]
# **Tiền xử lý - với cột ``Source``**

# %%
data['Source'] = data['Source'].str.replace('<.*?>', '', regex=True)
data['Source'].sample(5)
# Out:
# 16971    Twitter for Websites
# 37139      Twitter for iPhone
# 71465         Twitter Web App
# 32860              Mobile Web
# 70778         Twitter Web App
# Name: Source, dtype: object

# %% [markdown]
# **Kiểu dữ liệu của mỗi cột sau khi tiền xử lý**

# %%
def open_object_dtype(s):
    dtypes = set()
    dtypes.update(s.apply(type))
    return dtypes

data.apply(open_object_dtype)
# Out:
# ID                                                    {<class 'str'>}
# Timestamp           {<class 'pandas._libs.tslibs.timestamps.Timest...
# User                                                  {<class 'str'>}
# Text                                                  {<class 'str'>}
# Hashtag                             {<class 'float'>, <class 'list'>}
# Retweets                                              {<class 'int'>}
# Likes                                                 {<class 'int'>}
# Replies                                               {<class 'int'>}
# Source                                                {<class 'str'>}
# Location                             {<class 'float'>, <class 'str'>}
# Verified_Account                                     {<class 'bool'>}
# Followers                                             {<class 'int'>}
# Following                                             {<class 'int'>}
# dtype: object

# %% [markdown]
# ## III - Phân tích dữ liệu để trả lời câu hỏi có ý nghĩa ##

# %% [markdown]
# ### 1. Các tài khoản đã xác minh thường sử dụng nguồn nào để đăng tweet? ###

# %% [markdown]
# **Bước 1**: Tìm những tài khoản nào nào có ``Verified_Account`` là ``True`` (những tài khoản đã được xác minh)

# %%
verif_acc = data[data['Verified_Account'] == True]

# %% [markdown]
# **Bước 2**: Đếm số lượng tài khoản đã xác minh đó dựa vào ``Source``

# %%
usual_source_from_verif_acc = verif_acc.groupby('Source')['Verified_Account'].count()
usual_source_from_verif_acc = pd.DataFrame(usual_source_from_verif_acc) # Chuyển thành dataframe
usual_source_from_verif_acc = usual_source_from_verif_acc.rename(columns={'Verified_Account': 'Count_Verified_Account'}) # Đổi tên cột
usual_source_from_verif_acc
# Out:
#                      Count_Verified_Account
# Source
# Adobe Express (old)                       1
# Adobe® Social                             2
# Agorapulse app                            2
# Besocy_Oficial                            1
# Brandwatch                                8
# ...                                     ...
# iOS                                       4
# idntimes live blog                        1
# pramborsfm.com                            1
# twitterfeed                              55
# wptwitters                                2
#
# [99 rows x 1 columns]

# %% [markdown]
# **Trực quan hóa dữ liệu thể hiện sự phân bố của các nguồn khác nhau được sử dụng bởi các tài khoản đã xác minh**

# %%
fig, ax = plt.subplots(figsize=(20, 18))
ax.barh(list(usual_source_from_verif_acc.index), usual_source_from_verif_acc['Count_Verified_Account'])
ax.set_title('Số lượng tài khoản đã xác minh sử dụng mỗi nguồn khác nhau')
ax.set_xlabel('Số lượng tài khoản')
ax.set_ylabel('Nguồn (Source)')
# Out:
# Text(0, 0.5, 'Nguồn (Source)')

# %% [markdown]
# **Các nguồn thường được các tài khoản đã xác minh cũng chính là top 3 số lượng tài khoản đã xác minh dựa vào ``Source`` cao nhất.**

# %%
usual_source_from_verif_acc.nlargest(3, 'Count_Verified_Account', keep='all')
# Out:
#                     Count_Verified_Account
# Source
# TweetDeck                             1230
# Twitter Web Client                     544
# Twitter for iPhone                     480

# %% [markdown]
# Như vậy, qua biểu đồ cũng như là kết quả của việc trích ba dòng có số lượng cao nhất, chúng em thấy rằng các tài khoản được xác minh thường sử dụng ứng dụng TweetDeck và Twitter từ Web Client hoặc thiết bị iPhone (TweetDeck, Twitter Web Client và Twitter for iPhone).

# %% [markdown]
# ### 2. Vào năm 2023, khung giờ đăng các tweets của top 10 người có số lượng followers nhiều nhất thường phổ biến nhất vào lúc nào?  ###

# %% [markdown]
# **Bước 1**: Tìm những tweets được đăng vào năm 2023

# %%
data_2023 = data[pd.DatetimeIndex(data['Timestamp']).year == 2023]
data_2023
# Out:
#                  ID                 Timestamp             User  \
# 110000  1.64484e+18 2023-04-08 23:10:30+00:00       RoseAlpaca
# 110001  1.64482e+18 2023-04-08 21:34:54+00:00      don_Raphina
# 110002   1.6448e+18 2023-04-08 20:38:35+00:00           FMLFPL
# 110003   1.6448e+18 2023-04-08 20:36:31+00:00      OfficialFPL
# 110004  1.64479e+18 2023-04-08 19:54:00+00:00      OfficialFPL
# ...             ...                       ...              ...
# 114461  1.60946e+18 2023-01-01 08:05:36+00:00       SaintyLife
# 114462   1.6094e+18 2023-01-01 04:11:09+00:00         defecamp
# 114463  1.60938e+18 2023-01-01 02:55:30+00:00        JosiahUTD
# 114464  1.60934e+18 2023-01-01 00:14:48+00:00          RDijkot
# 114465  1.60934e+18 2023-01-01 00:08:04+00:00  Asparagus_Brown
#
#                                                      Text            Hashtag  \
# 110000  Current fantasy teams (position in overall)\n•...                NaN
# 110001  @vcosmas_030 FPL \nFantasy premier league \nIt...                NaN
# 110002                             @FFCasualsPod nice one                NaN
# 110003  ⚽️ 9 goals\n🎯 2 assists\n\nOllie Watkins (£7.6...                NaN
# 110004                         🚨 BONUS POINTS CONFIRMED 🚨                NaN
# ...                                                   ...                ...
# 114461  My FPL Gameweek 19 Kneejerk Reaction | Transfe...                NaN
# 114462  @Jim_Keoghan Come on, he was my captain in fan...                NaN
# 114463                    @wapzzgo Fantasy Premier League                NaN
# 114464  WOL vs MUN Dream11 Prediction, Fantasy Footbal...  [cricket, sports]
# 114465  One of my dumbest achievements has been doing ...                NaN
#
#         Retweets  Likes  Replies                   Source  \
# 110000         0      2        0      Twitter for Android
# 110001         0      0        1       Twitter for iPhone
# 110002         0      1        1       Twitter for iPhone
# 110003       112   4067       51        Khoros Publishing
# 110004        83   1999       39  Twitter for Advertisers
# ...          ...    ...      ...                      ...
# 114461         0      0        0          Twitter Web App
# 114462         0      0        0       Twitter for iPhone
# 114463         0      2        1       Twitter for iPhone
# 114464         0      0        0              Jetpack.com
# 114465         0      2        0      Twitter for Android
#
#                     Location  Verified_Account  Followers  Following
# 110000                   NaN             False          2          1
# 110001      Raphinha’s heart             False       1629       1333
# 110002         United States             False      23828        997
# 110003                   NaN             False    5125477         23
# 110004                   NaN             False    5125477         23
# ...                      ...               ...        ...        ...
# 114461  Capetown, South Ah!              False        321        503
# 114462                   NaN             False         24        130
# 114463                                  False       1985       3535
# 114464           los Angeles             False       1154       1266
# 114465                 Naarm             False        374        877
#
# [4466 rows x 13 columns]

# %% [markdown]
# **Bước 2**: Tìm những tài khoản có top 10 số lượng followers nhiều nhất

# %%
data_top_10_followers_2023 = data_2023.nlargest(10, 'Followers', keep='all')
data_top_10_followers_2023
# Out:
#                  ID                 Timestamp           User  \
# 110198   1.6445e+18 2023-04-08 00:58:16+00:00       BBCWorld
# 110179   1.6446e+18 2023-04-08 07:29:41+00:00        BBCNews
# 111000  1.64182e+18 2023-03-31 15:00:07+00:00    SkySportsPL
# 110217   1.6444e+18 2023-04-07 18:00:30+00:00    SkySportsPL
# 112165  1.62845e+18 2023-02-22 17:45:00+00:00       guardian
# 113693  1.62003e+18 2023-01-30 12:00:22+00:00     TechCrunch
# 113094  1.62052e+18 2023-01-31 20:44:00+00:00  CoinMarketCap
# 111002  1.64179e+18 2023-03-31 13:05:35+00:00    OfficialFPL
# 111005  1.64178e+18 2023-03-31 12:47:04+00:00    OfficialFPL
# 111006  1.64178e+18 2023-03-31 12:45:05+00:00    OfficialFPL
# 111008  1.64178e+18 2023-03-31 12:42:24+00:00    OfficialFPL
# 111009  1.64178e+18 2023-03-31 12:41:24+00:00    OfficialFPL
# 111010  1.64178e+18 2023-03-31 12:39:34+00:00    OfficialFPL
# 111011  1.64178e+18 2023-03-31 12:36:28+00:00    OfficialFPL
# 111013  1.64178e+18 2023-03-31 12:33:37+00:00    OfficialFPL
# 111014  1.64178e+18 2023-03-31 12:30:31+00:00    OfficialFPL
# 111017  1.64178e+18 2023-03-31 12:17:51+00:00    OfficialFPL
# 111018  1.64177e+18 2023-03-31 11:52:52+00:00    OfficialFPL
# 111032  1.64173e+18 2023-03-31 09:18:35+00:00    OfficialFPL
# 111047  1.64171e+18 2023-03-31 07:37:44+00:00    OfficialFPL
#
#                                                      Text  \
# 110198  Premier League fantasy football tips from the ...
# 110179  Premier League fantasy football tips from the ...
# 111000  Reply to this tweet with your FPL questions an...
# 110217  Who should you sign to give you the edge in fa...
# 112165  A three-way title race is unusual, but the ide...
# 113693  Sorare teams up with the Premier League for it...
# 113094  #cryptonews: The Premier League has teamed up ...
# 111002  Mikel Arteta provides an update on William Sal...
# 111005  @georgeallen87 @DanielR39554785 You gonna take...
# 111006     @_the_bigboy Team 'lemon head', watch out... 👀
# 111008                   @thesway__ Sit back and enjoy 🏖️
# 111009      @onlyonephilip @Silassss_ Game on, love it! 😅
# 111010  @hEnRy_265 He went there! https://t.co/wTr8P6Q6El
# 111011                    @CTE1 We don't make the rules 🤷
# 111013                           @ManCity Pep gonna Pep 😅
# 111014  Tag a manager in your mini-league that you're ...
# 111017  @foffalang @premierleague @EASPORTSFIFA @Bukay...
# 111018  @premierleague @EASPORTSFIFA @BukayoSaka87 @Ar...
# 111032  📉 Two @Arsenal assets are #FPL price fallers 📉...
# 111047  #FPL 🤝 @EASPORTSFIFA \n\n2022/23 #ePremierLeag...
#
#                               Hashtag  Retweets  Likes  Replies  \
# 110198                            NaN        25    164       18
# 110179                            NaN         6     36       10
# 111000                            NaN        20    375       24
# 110217                            NaN        11    294       13
# 112165                            NaN         0     14        8
# 113693                            NaN         1      9        1
# 113094              [cryptonews, nft]        19    113       55
# 111002                  [fpl, arslee]        85   1663       31
# 111005                            NaN         0      4        1
# 111006                            NaN         1     10        0
# 111008                            NaN         0      7        1
# 111009                            NaN         2      2        0
# 111010                            NaN         1     26        1
# 111011                            NaN         1      7        1
# 111013                            NaN        14    269        6
# 111014                            NaN        38    800      330
# 111017                            NaN         0      0        0
# 111018                          [fpl]        25    437       20
# 111032                          [fpl]       138   4614       46
# 111047  [fpl, epremierleague, fplpod]        50   1267       29
#
#                          Source           Location  Verified_Account  \
# 110198               SocialFlow         London, UK              True
# 110179               SocialFlow             London              True
# 111000  Twitter for Advertisers             London              True
# 110217     Twitter Media Studio             London              True
# 112165                TweetDeck             London              True
# 113693               SocialFlow  San Francisco, CA              True
# 113094                TweetDeck      Decentralized              True
# 111002        Khoros Publishing                NaN             False
# 111005          Twitter Web App                NaN             False
# 111006          Twitter Web App                NaN             False
# 111008          Twitter Web App                NaN             False
# 111009          Twitter Web App                NaN             False
# 111010          Twitter Web App                NaN             False
# 111011          Twitter Web App                NaN             False
# 111013                TweetDeck                NaN             False
# 111014        Khoros Publishing                NaN             False
# 111017                TweetDeck                NaN             False
# 111018                TweetDeck                NaN             False
# 111032        Khoros Publishing                NaN             False
# 111047        Khoros Publishing                NaN             False
#
#         Followers  Following
# 110198   39719716         17
# 110179   15094001         84
# 111000   10939587         35
# 110217   10939585         35
# 112165   10895788       1051
# 113693   10269635        443
# 113094    5864731       1925
# 111002    5125480         23
# 111005    5125480         23
# 111006    5125480         23
# 111008    5125480         23
# 111009    5125480         23
# 111010    5125480         23
# 111011    5125480         23
# 111013    5125480         23
# 111014    5125480         23
# 111017    5125480         23
# 111018    5125480         23
# 111032    5125480         23
# 111047    5125480         23

# %% [markdown]
# **Bước 3**: Tính tổng số lượng followers cũa mỗi tweet dựa vào khung giờ

# %% [markdown]
# Với mỗi dòng tweets, chúng em chỉ lấy giờ từ cột timestamp và đưa ra một cột mới có tên là ``Hour``

# %%
hour_lst = pd.DatetimeIndex(data_top_10_followers_2023['Timestamp']).hour
data_top_10_followers_2023.insert(2, "Hour_Range", hour_lst)
data_top_10_followers_2023
# Out:
#                  ID                 Timestamp  Hour_Range           User  \
# 110198   1.6445e+18 2023-04-08 00:58:16+00:00           0       BBCWorld
# 110179   1.6446e+18 2023-04-08 07:29:41+00:00           7        BBCNews
# 111000  1.64182e+18 2023-03-31 15:00:07+00:00          15    SkySportsPL
# 110217   1.6444e+18 2023-04-07 18:00:30+00:00          18    SkySportsPL
# 112165  1.62845e+18 2023-02-22 17:45:00+00:00          17       guardian
# 113693  1.62003e+18 2023-01-30 12:00:22+00:00          12     TechCrunch
# 113094  1.62052e+18 2023-01-31 20:44:00+00:00          20  CoinMarketCap
# 111002  1.64179e+18 2023-03-31 13:05:35+00:00          13    OfficialFPL
# 111005  1.64178e+18 2023-03-31 12:47:04+00:00          12    OfficialFPL
# 111006  1.64178e+18 2023-03-31 12:45:05+00:00          12    OfficialFPL
# 111008  1.64178e+18 2023-03-31 12:42:24+00:00          12    OfficialFPL
# 111009  1.64178e+18 2023-03-31 12:41:24+00:00          12    OfficialFPL
# 111010  1.64178e+18 2023-03-31 12:39:34+00:00          12    OfficialFPL
# 111011  1.64178e+18 2023-03-31 12:36:28+00:00          12    OfficialFPL
# 111013  1.64178e+18 2023-03-31 12:33:37+00:00          12    OfficialFPL
# 111014  1.64178e+18 2023-03-31 12:30:31+00:00          12    OfficialFPL
# 111017  1.64178e+18 2023-03-31 12:17:51+00:00          12    OfficialFPL
# 111018  1.64177e+18 2023-03-31 11:52:52+00:00          11    OfficialFPL
# 111032  1.64173e+18 2023-03-31 09:18:35+00:00           9    OfficialFPL
# 111047  1.64171e+18 2023-03-31 07:37:44+00:00           7    OfficialFPL
#
#                                                      Text  \
# 110198  Premier League fantasy football tips from the ...
# 110179  Premier League fantasy football tips from the ...
# 111000  Reply to this tweet with your FPL questions an...
# 110217  Who should you sign to give you the edge in fa...
# 112165  A three-way title race is unusual, but the ide...
# 113693  Sorare teams up with the Premier League for it...
# 113094  #cryptonews: The Premier League has teamed up ...
# 111002  Mikel Arteta provides an update on William Sal...
# 111005  @georgeallen87 @DanielR39554785 You gonna take...
# 111006     @_the_bigboy Team 'lemon head', watch out... 👀
# 111008                   @thesway__ Sit back and enjoy 🏖️
# 111009      @onlyonephilip @Silassss_ Game on, love it! 😅
# 111010  @hEnRy_265 He went there! https://t.co/wTr8P6Q6El
# 111011                    @CTE1 We don't make the rules 🤷
# 111013                           @ManCity Pep gonna Pep 😅
# 111014  Tag a manager in your mini-league that you're ...
# 111017  @foffalang @premierleague @EASPORTSFIFA @Bukay...
# 111018  @premierleague @EASPORTSFIFA @BukayoSaka87 @Ar...
# 111032  📉 Two @Arsenal assets are #FPL price fallers 📉...
# 111047  #FPL 🤝 @EASPORTSFIFA \n\n2022/23 #ePremierLeag...
#
#                               Hashtag  Retweets  Likes  Replies  \
# 110198                            NaN        25    164       18
# 110179                            NaN         6     36       10
# 111000                            NaN        20    375       24
# 110217                            NaN        11    294       13
# 112165                            NaN         0     14        8
# 113693                            NaN         1      9        1
# 113094              [cryptonews, nft]        19    113       55
# 111002                  [fpl, arslee]        85   1663       31
# 111005                            NaN         0      4        1
# 111006                            NaN         1     10        0
# 111008                            NaN         0      7        1
# 111009                            NaN         2      2        0
# 111010                            NaN         1     26        1
# 111011                            NaN         1      7        1
# 111013                            NaN        14    269        6
# 111014                            NaN        38    800      330
# 111017                            NaN         0      0        0
# 111018                          [fpl]        25    437       20
# 111032                          [fpl]       138   4614       46
# 111047  [fpl, epremierleague, fplpod]        50   1267       29
#
#                          Source           Location  Verified_Account  \
# 110198               SocialFlow         London, UK              True
# 110179               SocialFlow             London              True
# 111000  Twitter for Advertisers             London              True
# 110217     Twitter Media Studio             London              True
# 112165                TweetDeck             London              True
# 113693               SocialFlow  San Francisco, CA              True
# 113094                TweetDeck      Decentralized              True
# 111002        Khoros Publishing                NaN             False
# 111005          Twitter Web App                NaN             False
# 111006          Twitter Web App                NaN             False
# 111008          Twitter Web App                NaN             False
# 111009          Twitter Web App                NaN             False
# 111010          Twitter Web App                NaN             False
# 111011          Twitter Web App                NaN             False
# 111013                TweetDeck                NaN             False
# 111014        Khoros Publishing                NaN             False
# 111017                TweetDeck                NaN             False
# 111018                TweetDeck                NaN             False
# 111032        Khoros Publishing                NaN             False
# 111047        Khoros Publishing                NaN             False
#
#         Followers  Following
# 110198   39719716         17
# 110179   15094001         84
# 111000   10939587         35
# 110217   10939585         35
# 112165   10895788       1051
# 113693   10269635        443
# 113094    5864731       1925
# 111002    5125480         23
# 111005    5125480         23
# 111006    5125480         23
# 111008    5125480         23
# 111009    5125480         23
# 111010    5125480         23
# 111011    5125480         23
# 111013    5125480         23
# 111014    5125480         23
# 111017    5125480         23
# 111018    5125480         23
# 111032    5125480         23
# 111047    5125480         23

# %% [markdown]
# **Bước 4**: Phân tích số lượng followers cũa mỗi tweet dựa vào khung giờ và chọn ra số lượng lớn nhất.

# %% [markdown]
# *Chúng em phân tích số lượng followers cũa mỗi tweet dựa vào khung giờ từ việc trực quan hóa dữ liệu bằng biểu đồ histogram*

# %%
plt.figure(figsize=(12,4))
plt.hist(data_top_10_followers_2023['Hour_Range'], bins=24, edgecolor='black')
plt.xticks(np.arange(0,24))
plt.title('Số lượng tweets do top 10 người dùng có số lượng followers nhiều nhất đăng lên dựa vào giờ')
plt.xlabel('Giờ (Hour)')
plt.ylabel('Số lượng tương tác')
# Out:
# Text(0, 0.5, 'Số lượng tương tác')

# %% [markdown]
# - Từ biểu đồ histogram này, chúng em thấy rằng vào năm 2023, khung giờ mà top 10 người có số lượng followers nhiều nhất đăng các tweets thường phổ biến nhiều nhất là từ 12 giờ đến trước 13 giờ.
# - Vào năm 2023, từ 1 giờ đến trước 7 giờ và từ 21 giờ đến trước 0h không có một lượt tương tác nào vì hai khung thời gian này thường họ ngủ hoặc đang làm việc đêm.

# %% [markdown]
# ### 3. Các user nào không được xác minh mà sở hữu  top 10 tweets có lượng tương tác nhiều nhất? ###

# %% [markdown]
# **Bước 1: Tạo cột tương tác bằng cách tổng hợp like, trả lời và retweet**

# %%
# Copy để tránh xung đột với dữ liệu gốc
non_verified_accounts_tweets = data.copy()

# Tiến hành lọc dữ liệu và thêm cột tương tác
non_verified_accounts_tweets = non_verified_accounts_tweets[non_verified_accounts_tweets['Verified_Account'] == False]
non_verified_accounts_tweets['Interaction'] = non_verified_accounts_tweets['Likes'] + non_verified_accounts_tweets['Replies'] + non_verified_accounts_tweets['Retweets']
sorted_tweets = non_verified_accounts_tweets.sort_values(by='Interaction', ascending=False)

# Hiển thị mẫu
top_10_tweets = sorted_tweets.head(10)
top_10_tweets
# Out:
#                  ID                 Timestamp           User  \
# 103613  1.57218e+18 2022-09-20 10:53:16+00:00  theMadridZone
# 87082   1.30951e+18 2020-09-25 15:14:48+00:00      utdreport
# 99658   1.42578e+18 2021-08-12 11:43:03+00:00      utdreport
# 106290   1.5607e+18 2022-08-19 18:45:00+00:00  FPLStatistics
# 110007  1.64478e+18 2023-04-08 19:10:58+00:00    OfficialFPL
# 110323  1.64395e+18 2023-04-06 12:05:35+00:00    OfficialFPL
# 110563  1.64316e+18 2023-04-04 08:10:31+00:00    OfficialFPL
# 110429  1.64357e+18 2023-04-05 11:20:32+00:00    OfficialFPL
# 104605  1.56571e+18 2022-09-02 14:42:36+00:00       debejota
# 110244  1.64432e+18 2023-04-07 12:37:59+00:00    OfficialFPL
#
#                                                      Text        Hashtag  \
# 103613  🎙️| Rüdiger: "I can't call Real Madrid a dream...            NaN
# 87082   Bruno Fernandes on who players should choose i...       [mulive]
# 99658   Luke Shaw is the most in demand player on Fant...       [mulive]
# 106290  Who said Fantasy Premier League isn't fun?\n\n...          [fpl]
# 110007  🅰️ Four assists\n\nA huge Saturday haul for No...          [fpl]
# 110323  With 1️⃣4️⃣3️⃣ points, your #FPL Manager of th...          [fpl]
# 110563  📈 On the up! 📈\n\n@Arsenal's Ben White is an #...          [fpl]
# 110429  Hands up if you're hoping to see this celebrat...  [munbre, fpl]
# 104605  Marçal acusa al Barça de falsear el precio del...            NaN
# 110244  Erling Haaland is ready 👀\n\nDoes this change ...          [fpl]
#
#         Retweets  Likes  Replies               Source             Location  \
# 103613      1449  32959       97   Twitter for iPhone                  NaN
# 87082        933  14137      172            TweetDeck  Manchester, England
# 99658        682  11458       73            TweetDeck  Manchester, England
# 106290       706   9643      200            TweetDeck                  NaN
# 110007       374   8784      125      Twitter Web App                  NaN
# 110323       283   7606      275    Khoros Publishing                  NaN
# 110563       241   7190       33    Khoros Publishing                  NaN
# 110429       284   6200      363    Khoros Publishing                  NaN
# 104605       780   5907      102  Twitter for Android                 Lugo
# 110244       260   6237      108    Khoros Publishing                  NaN
#
#         Verified_Account  Followers  Following  Interaction
# 103613             False     638121        184        34505
# 87082              False    1378185        128        15242
# 99658              False    1378193        128        12213
# 106290             False      31568         56        10549
# 110007             False    5125477         23         9283
# 110323             False    5125478         23         8164
# 110563             False    5125479         23         7464
# 110429             False    5125478         23         6847
# 104605             False      15079        496         6789
# 110244             False    5125478         23         6605

# %% [markdown]
# **Bước 2: Chọn bảng màu và kích cỡ phù hợp**

# %%
# Lấy một bảng màu từ colormap của matplotlib
plt.figure(figsize=(12, 6))
colors = plt.cm.Set3(np.linspace(0, 1, 3))

# %% [markdown]
# **Bước 3: Tạo biểu đồ cột với 3 phần tương ứng với số lượng like, retweet và trả lời**

# %%
# Tạo một mảng để lưu trữ vị trí x cho Likes, Retweets, Replies
x = np.arange(len(top_10_tweets['User']))

# Bar chart cho Likes
plt.bar(x - 0.2, top_10_tweets['Likes'], width=0.2, color=colors[0], label='Likes')

# Bar chart cho Retweets
plt.bar(x, top_10_tweets['Retweets'], width=0.2, color=colors[1], label='Retweets')

# Bar chart cho Replies
plt.bar(x + 0.2, top_10_tweets['Replies'], width=0.2, color=colors[2], label='Replies')

plt.xlabel('User')
plt.ylabel('Total Interaction')
plt.title('Top Non-Verified Accounts based on 10 Most Interaction Tweets ')
plt.legend(title='Interactions', loc='upper right')
plt.xticks(x, top_10_tweets['User'], rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 13
#      11 plt.bar(x + 0.2, top_10_tweets['Replies'], width=0.2, color=colors[2], label='Replies')
#      12 for i, (user, text) in enumerate(zip(top_10_tweets['User'], top_10_tweets['Text'])):
# ---> 13     plt.text(i, max(top_10_tweets['Likes'][i], top_10_tweets['Retweets'][i], top_10_tweets['Replies'][i]) + 5,
#      14              f"{user}\n{str(text)[:20]}...", ha='center', va='bottom', rotation=45, color='black')
#      15 plt.xlabel('User')
#      16 plt.ylabel('Total Interaction')
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %% [markdown]
# ### 4. Qua từng năm, những hashtag nào được tương tác nhiều nhất của các tài khoản được xác minh?  ###

# %% [markdown]
# **Bước 1: Xử lý, lọc dữ liệu cho phù hợp**

# %%
#Copy dữ liệu lại để tránh xung đột
data_with_hashtags = data.copy(deep=True)

#Xử lý, lọc dữ liệu, tách hashtag
data_with_hashtags['Timestamp'] = pd.to_datetime(data_with_hashtags['Timestamp'])
data_with_hashtags['Year'] = data_with_hashtags['Timestamp'].dt.year
data_with_hashtags_exploded = data_with_hashtags.explode('Hashtag')
data_with_hashtags_exploded = data_with_hashtags_exploded[data_with_hashtags_exploded['Verified_Account'] == True]

# %% [markdown]
# **Bước 1: Xử lý, lọc dữ liệu cho phù hợp**

# %%
# Groupby theo năm và hashtag, đếm số lượng tương tác
grouped_data = data_with_hashtags_exploded.groupby(['Year', 'Hashtag']).agg({
    'Likes': 'sum',
    'Replies': 'sum',
    'Retweets': 'sum'
}).reset_index()

# Tính tổng số lượng tương tác (Interaction Count)
grouped_data['Interaction_Count'] = grouped_data['Likes'] + grouped_data['Replies'] + grouped_data['Retweets']
grouped_data

# Lấy top 3 hashtag có tương tác lớn nhất mỗi năm
top_hashtags_by_year = grouped_data.groupby('Year').apply(lambda x: x.nlargest(3, 'Interaction_Count')).reset_index(drop=True)

# %%
# Set up the plot
plt.figure(figsize=(12, 6))

# Get unique hashtags
unique_hashtags = top_hashtags_by_year['Hashtag'].unique()

# Chọn một palette màu
color_palette = sns.color_palette("husl", n_colors=len(unique_hashtags))

# Vẽ theo palette màu
sns.lineplot(data=top_hashtags_by_year, x='Year', y='Interaction_Count', hue='Hashtag', marker='o', palette=color_palette)

plt.xlabel('Year')
plt.ylabel('Interaction Count')
plt.title('Top 3 hashtags 2012 - 2023')

# Tạo chú thích theo năm
legend_labels = [f"{hashtag} ({' - '.join(top_hashtags_by_year[top_hashtags_by_year['Hashtag'] == hashtag]['Year'].astype(str).tolist())})" for hashtag in unique_hashtags]

# Get handles for legend
handles = [plt.Line2D([0], [0], color=color_palette[i], marker='o', linestyle='-', linewidth=2, markersize=8) for i in range(len(unique_hashtags))]

# Hiển
plt.legend(handles=handles, labels=legend_labels, title='Hashtags', loc='upper center', bbox_to_anchor=(0.5, -0.2), fancybox=True, shadow=True, ncol=3)

plt.show()
# Out:
# /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 12450 (\N{KATAKANA LETTER A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 12475 (\N{KATAKANA LETTER SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 12490 (\N{KATAKANA LETTER NA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/datbui/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 12523 (\N{KATAKANA LETTER RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 5. Thái độ hưởng ứng của cộng đồng đối với các sự kiện (hashtag)

# %% [markdown]
# **Bước 1: xác định các hashtag và số lần xuất hiện của mỗi hashtag trong tất cả tweet**

# %% [markdown]
# *Bước 1.1: chuyển cột hashtag thành 1 pandas series (gồm các dòng) và loại bỏ giá trị nan*

# %%
# create dataframe
hashtag_df = pd.DataFrame(columns=['hashtag_name', 'count', 'positive_text', 'negative_text'])

# 1. convert Pandas Series of lists into one series and remove nan (https://stackoverflow.com/questions/30885005/pandas-series-of-lists-to-one-series)
temp = data['Hashtag'].explode()
temp = temp.dropna()
temp
# Out:
# 4                   fpl
# 4            aiminghigh
# 7                winnar
# 18               suarez
# 18              lambert
#               ...
# 114457    premiereleven
# 114460    premierleague
# 114460           notche
# 114464          cricket
# 114464           sports
# Name: Hashtag, Length: 63008, dtype: object

# %% [markdown]
# *Bước 1.2: tìm và đếm số lần xuất hiện của các hashtag dựa trên dữ liệu vừa có được*

# %%
# 1. find unique hashtag and occurrence of each (for timesaving, just considered hastag at row 99 and 100 based on print out result)
temp = temp.value_counts().iloc[99:101]

# 2. assign to dataframe
hashtag_df['hashtag_name'] = temp.index
hashtag_df['count'] = temp.values
hashtag_df
# Out:
#      hashtag_name  count positive_text negative_text
# 0              uk     62           NaN           NaN
# 1  teamfollowback     62           NaN           NaN

# %% [markdown]
# **Bước 2: phân loại nội dung bình luận của các tweets có hashtag tương ứng**

# %% [markdown]
# *Bước 2.1: chọn ra nội dung của các tweet có hashtag*

# %%
temp = data.loc[:, ['Text', 'Hashtag']]
# nan values' location
condition = pd.isnull(temp['Hashtag'])
# tweets which have hashtag(s)
temp = temp.loc[~condition, :]
temp.sample(5)
# Out:
#                                                     Text  \
# 56204  Fantasy Premier League Gameweek 33 : Injury up...
# 26801  All the best pick-ups &amp; other fantasy tips...
# 10853  Bold choice of captain today in my fantasy pre...
# 72368  @FFScout 🚨 £10,000 Premier League freeroll fan...
# 25006  No Premier League last weekend. The fantasy fo...
#
#                       Hashtag
# 56204  [fantasypremierleague]
# 26801                [rbmffl]
# 10853                 [hcafc]
# 72368    [fpl, premierleague]
# 25006            [jjfootball]

# %% [markdown]
# *Bước 2.2: phân loại bình luận*

# %%
# sentiment analysis pretrained model
sentiment_pipeline = pipeline(model="distilbert-base-uncased-finetuned-sst-2-english")

def sentiment_process(hashtag):
    # sentiment dictionary
    sentiment_dict = {'POSITIVE': 0,
                     'NEGATIVE': 0}

    # for every index of temp, get the sentiment analysis if there is the hashtag 
    for i in temp.index:
        # sentiment analysis if tweet has the hashtag
        if hashtag in temp['Hashtag'][i]:
            
            # sentiment analysis
            sentiment_res = sentiment_pipeline(list(temp['Text'][i])) # result: [{'label': 'POSITIVE' or 'NEGATIVE', 'score': 0...}]
            sentiment_dict[sentiment_res[0]['label']] += 1

    # assign result to dataframe
    hashtag_df.loc[hashtag_df['hashtag_name']==hashtag, 'positive_text'] = sentiment_dict['POSITIVE']
    hashtag_df.loc[hashtag_df['hashtag_name']==hashtag, 'negative_text'] = sentiment_dict['NEGATIVE']
    
hashtag_df['hashtag_name'].apply(sentiment_process)
hashtag_df
# Out:
# 2023-12-26 18:52:50.105495: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-26 18:52:50.144976: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-26 18:52:50.145073: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-26 18:52:50.149744: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-26 18:52:50.149849: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-26 18:52:50.149890: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[22], line 2
#       1 # sentiment analysis pretrained model
# ----> 2 sentiment_pipeline = pipeline(model="distilbert-base-uncased-finetuned-sst-2-english")
#       4 def sentiment_process(hashtag):
#       5     # sentiment dictionary
#       6     sentiment_dict = {'POSITIVE': 0,
#       7                      'NEGATIVE': 0}
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/transformers/pipelines/__init__.py:870, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     868 if isinstance(model, str) or framework is None:
#     869     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 870     framework, model = infer_framework_load_model(
#     871         model,
#     872         model_classes=model_classes,
#     873         config=config,
#     874         framework=framework,
#     875         task=task,
#     876         **hub_kwargs,
#     877         **model_kwargs,
#     878     )
#     880 model_config = model.config
#     881 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/transformers/pipelines/base.py:269, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     263     logger.warning(
#     264         "Model might be a PyTorch model (ending with `.bin`) but PyTorch is not available. "
#     265         "Trying to load the model with Tensorflow."
#     266     )
#     268 try:
# --> 269     model = model_class.from_pretrained(model, **kwargs)
#     270     if hasattr(model, "eval"):
#     271         model = model.eval()
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:566, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     564 elif type(config) in cls._model_mapping.keys():
#     565     model_class = _get_model_class(config, cls._model_mapping)
# --> 566     return model_class.from_pretrained(
#     567         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     568     )
#     569 raise ValueError(
#     570     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     571     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     572 )
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/transformers/modeling_tf_utils.py:2893, in TFPreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, *model_args, **kwargs)
#    2890     model_kwargs["load_weight_prefix"] = load_weight_prefix + "/" + model_kwargs.get("name")
#    2892 # Instantiate model.
# -> 2893 model = cls(config, *model_args, **model_kwargs)
#    2895 if tf_to_pt_weight_rename is None and hasattr(model, "tf_to_pt_weight_rename"):
#    2896     # TODO Matt: This is a temporary workaround to allow weight renaming, but requires a method
#    2897     #            to be defined for each class that requires a rename. We can probably just have a class-level
#    2898     #            dict and a single top-level method or something and cut down a lot of boilerplate code
#    2899     tf_to_pt_weight_rename = model.tf_to_pt_weight_rename
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/transformers/models/distilbert/modeling_tf_distilbert.py:680, in TFDistilBertForSequenceClassification.__init__(self, config, *inputs, **kwargs)
#     679 def __init__(self, config, *inputs, **kwargs):
# --> 680     super().__init__(config, *inputs, **kwargs)
#     681     self.num_labels = config.num_labels
#     683     self.distilbert = TFDistilBertMainLayer(config, name="distilbert")
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/transformers/modeling_tf_utils.py:1144, in TFPreTrainedModel.__init__(self, config, *inputs, **kwargs)
#    1143 def __init__(self, config, *inputs, **kwargs):
# -> 1144     super().__init__(*inputs, **kwargs)
#    1145     if not isinstance(config, PretrainedConfig):
#    1146         raise ValueError(
#    1147             f"Parameter config in `{self.__class__.__name__}(config)` should be an instance of class "
#    1148             "`PretrainedConfig`. To create a model from a pretrained model use "
#    1149             f"`model = {self.__class__.__name__}.from_pretrained(PRETRAINED_MODEL_NAME)`"
#    1150         )
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/tensorflow/python/trackable/base.py:204, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     202 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203 try:
# --> 204   result = method(self, *args, **kwargs)
#     205 finally:
#     206   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.10/site-packages/tensorflow/python/eager/context.py:603, in Context.ensure_initialized(self)
#     600   pywrap_tfe.TFE_ContextOptionsSetRunEagerOpAsFunction(opts, True)
#     601   pywrap_tfe.TFE_ContextOptionsSetJitCompileRewrite(
#     602       opts, self._jit_compile_rewrite)
# --> 603   context_handle = pywrap_tfe.TFE_NewContext(opts)
#     604 finally:
#     605   pywrap_tfe.TFE_DeleteContextOptions(opts)
#
# InternalError: cudaGetDevice() failed. Status: CUDA driver version is insufficient for CUDA runtime version

# %% [markdown]
# *Bước 2.3: vẽ biểu đồ cột đôi để trực quan thái độ của cộng đồng với các hashtag*

# %%
# Setup location of hashtag name
xticks_num = hashtag_df.shape[0]
r = np.arange(xticks_num)
width = 0.2

# Initialize bars
plt.bar(r, hashtag_df['positive_text'], width = width, edgecolor = 'black', label='Positive comment') 
plt.bar(r + width, hashtag_df['negative_text'], width = width, edgecolor = 'black', label='Negative comment')

# Labels, xtick, legend
plt.xlabel("Hashtag name") 
plt.ylabel("Comment count") 
plt.xticks(r + width/2, list(hashtag_df['hashtag_name'])) 
plt.legend()

# %% [markdown]
# ## IV - Reflection ##
